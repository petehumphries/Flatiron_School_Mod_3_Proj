# %% [markdown]
# ## Carbon Emissions Data Cleansing and Exploration
#
# Exec Summary Will go here:

# %%
import pandas as pd
import numpy as np
from numpy import mean
from numpy import std
import matplotlib.pyplot as plt
import seaborn as sns
import statsmodels.api as sm
from statsmodels.formula.api import ols
import math
# %matplotlib inline

# %%
df = pd.read_csv('predicting_carbon_emissions_cleaned.csv')
pd.set_option('display.max_columns', None)
df.columns = df.columns.str.strip().str.replace(' ', '_')

# %%
df = df[df.angerindex != 0]

# %%
df = df.rename(columns = {'Carbon_Emission__tCO2e/mmUSD':'Carbon'})

# %%
df.head(3)
# Out:
#    Unnamed:_0        Company_Name Listed HQ_Country             GICS_Sector  \
# 2           3              YPF SA    Yes  Argentina                  Energy
# 5           6  Aristocrat Leisure    Yes  Australia  Consumer Discretionary
# 6           7                 ALS    Yes  Australia             Industrials
#
#   Accounting_Year_End  Reported_Scope_1_tCO2e  Estimated_Scope_1_tCO2e  \
# 2          31/12/2016                     0.0               12000000.0
# 5          29/09/2016                     0.0                  21000.0
# 6          30/03/2017                     0.0                  12000.0
#
#                                    Scope_1_source  Scope_1_quality_flag  \
# 2  Estimated: Oil & Gas Extraction, O&G  Refining                   6.0
# 5                            Estimated: Gamma GLM                   3.0
# 6                            Estimated: Gamma GLM                   4.0
#
#   Reported_market-based_Scope_2_tCO2e  Note  \
# 2                                 NaN   NA
# 5                                 NaN   NA
# 6                                 NaN   NA
#
#    Reported_location-based_Scope_2_tCO2e  \
# 2                                    0.0
# 5                                    0.0
# 6                                    0.0
#
#    Estimated_location-based_Scope_2_tCO2e  \
# 2                               1200000.0
# 5                                 54000.0
# 6                                  3700.0
#
#                        Location-based_Scope_2_source  \
# 2     Estimated: Oil & Gas Extraction, O&G  Refining
# 5  Estimated: IEA National Grid Emissions Factor ...
# 6  Estimated: IEA National Grid Emissions Factor ...
#
#    Location-based_Scope_2_quality_flag Scope_2_company_comments  \
# 2                                  6.0                      NaN
# 5                                  2.0                      NaN
# 6                                  5.0                      NaN
#
#    GHG_revenue_intensity_tCO2e/mmUSD Scope_2_figure_used_for_intensity  \
# 2                             926.11                    Location-based
# 5                              47.82                    Location-based
# 6                              16.39                    Location-based
#
#    amplification.wordsindex  DeAmplification.wordsindex  HE_negativeindex  \
# 2                        48                          84               165
# 5                       114                          35                20
# 6                       123                         190                71
#
#    HE_positiveindex  angerindex  anticipationindex  disgustindex  fearindex  \
# 2               110         102                123           221         87
# 5               143         135                 98            76         99
# 6                78         115                 78           145         87
#
#    joyindex  sadnessindex  surpriseindex  trustindex  LMnegativeindex  \
# 2        69            86            102          72               89
# 5       112            64             89          94               73
# 6        83            64             86          79              106
#
#    LMpositiveindex  LMuncertaintyindex  BasicNegativeWordsindex  \
# 2               62                  75                       98
# 5              119                  70                       71
# 6               93                 113                       84
#
#    PositivePolarisedindex  NegativePolarisedindex  PowerWordsindex  \
# 2                      73                      98               94
# 5                     113                      71               87
# 6                     103                      84               88
#
#    PrudentialNegativeindex  PrudentialPositiveindex  \
# 2                       55                       89
# 5                       86                       94
# 6                       98                      153
#
#   PrudentialTopNegativeindex Strategyindex  Financial.termsindex  \
# 2                        170             0                    98
# 5                          0           316                    99
# 6                        364            31                    90
#
#    Regulationindex  Technologyindex Healthcareindex Environmentindex  \
# 2              111               14               0               87
# 5               75              266               0               65
# 6               36               10              75              186
#
#   Socialindex  Governanceindex  ESGindex  LMuncertaintyindex.1  \
# 2          26              130        90                  0.23
# 5       1,375               70       451                  0.26
# 6           0               40        80                  0.08
#
#    Regulationindex.1  Environmentindex.1  Socialindex.1  Governanceindex.1  \
# 2               0.12                0.23           0.07               0.13
# 5               0.24                0.00           0.15               0.01
# 6               0.19                0.25           0.21               0.15
#
#    ESGindex.1    ISIN_lower   2016vol   2017vol   2018vol   2019vol  \
# 2        0.27  arp9897x1319  0.024063  0.021263  0.030650  0.029235
# 5        0.14  au000000all7  0.019772  0.013992  0.018362  0.019044
# 6        0.11           NaN       NaN       NaN       NaN       NaN
#
#    VolFactor      Carbon  Scope_1_tCO2e  Scope_2_tCO2e  Scope_1_and_2_tCO2e  \
# 2   0.064662  926.111720     12000000.0      1200000.0           13200000.0
# 5   0.254386   47.820958        21000.0        54000.0              75000.0
# 6   0.000000   16.392587        12000.0         3700.0              15700.0
#
#    Consumer_Discretionary  Consumer_Staples  Energy  Financials  Health_Care  \
# 2                       0                 0       1           0            0
# 5                       1                 0       0           0            0
# 6                       0                 0       0           0            0
#
#    Industrials  Information_Technology  Materials  Real_Estate  \
# 2            0                       0          0            0
# 5            0                       0          0            0
# 6            1                       0          0            0
#
#    Telecommunication_Services  Utilities
# 2                           0          0
# 5                           0          0
# 6                           0          0

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1265 entries, 2 to 3938
# Data columns (total 77 columns):
# Unnamed:_0                                1265 non-null int64
# Company_Name                              1265 non-null object
# Listed                                    1265 non-null object
# HQ_Country                                1265 non-null object
# GICS_Sector                               1265 non-null object
# Accounting_Year_End                       1265 non-null object
# Reported_Scope_1_tCO2e                    1265 non-null float64
# Estimated_Scope_1_tCO2e                   1265 non-null float64
# Scope_1_source                            1265 non-null object
# Scope_1_quality_flag                      1062 non-null float64
# Reported_market-based_Scope_2_tCO2e       396 non-null object
# Note                                      1265 non-null object
# Reported_location-based_Scope_2_tCO2e     1265 non-null float64
# Estimated_location-based_Scope_2_tCO2e    1265 non-null float64
# Location-based_Scope_2_source             1257 non-null object
# Location-based_Scope_2_quality_flag       1063 non-null float64
# Scope_2_company_comments                  366 non-null object
# GHG_revenue_intensity_tCO2e/mmUSD         1264 non-null float64
# Scope_2_figure_used_for_intensity         1265 non-null object
# amplification.wordsindex                  1265 non-null int64
# DeAmplification.wordsindex                1265 non-null int64
# HE_negativeindex                          1265 non-null int64
# HE_positiveindex                          1265 non-null int64
# angerindex                                1265 non-null int64
# anticipationindex                         1265 non-null int64
# disgustindex                              1265 non-null int64
# fearindex                                 1265 non-null int64
# joyindex                                  1265 non-null int64
# sadnessindex                              1265 non-null int64
# surpriseindex                             1265 non-null int64
# trustindex                                1265 non-null int64
# LMnegativeindex                           1265 non-null int64
# LMpositiveindex                           1265 non-null int64
# LMuncertaintyindex                        1265 non-null int64
# BasicNegativeWordsindex                   1265 non-null int64
# PositivePolarisedindex                    1265 non-null int64
# NegativePolarisedindex                    1265 non-null int64
# PowerWordsindex                           1265 non-null int64
# PrudentialNegativeindex                   1265 non-null int64
# PrudentialPositiveindex                   1265 non-null int64
# PrudentialTopNegativeindex                1265 non-null object
# Strategyindex                             1265 non-null object
# Financial.termsindex                      1265 non-null int64
# Regulationindex                           1265 non-null int64
# Technologyindex                           1265 non-null int64
# Healthcareindex                           1265 non-null object
# Environmentindex                          1265 non-null object
# Socialindex                               1265 non-null object
# Governanceindex                           1265 non-null int64
# ESGindex                                  1265 non-null int64
# LMuncertaintyindex.1                      1265 non-null float64
# Regulationindex.1                         1265 non-null float64
# Environmentindex.1                        1265 non-null float64
# Socialindex.1                             1265 non-null float64
# Governanceindex.1                         1265 non-null float64
# ESGindex.1                                1265 non-null float64
# ISIN_lower                                1169 non-null object
# 2016vol                                   1093 non-null float64
# 2017vol                                   1093 non-null float64
# 2018vol                                   1074 non-null float64
# 2019vol                                   1070 non-null float64
# VolFactor                                 1265 non-null float64
# Carbon_Emission__tCO2e/mmUSD              1265 non-null float64
# Scope_1_tCO2e                             1265 non-null float64
# Scope_2_tCO2e                             1265 non-null float64
# Scope_1_and_2_tCO2e                       1265 non-null float64
# Consumer_Discretionary                    1265 non-null int64
# Consumer_Staples                          1265 non-null int64
# Energy                                    1265 non-null int64
# Financials                                1265 non-null int64
# Health_Care                               1265 non-null int64
# Industrials                               1265 non-null int64
# Information_Technology                    1265 non-null int64
# Materials                                 1265 non-null int64
# Real_Estate                               1265 non-null int64
# Telecommunication_Services                1265 non-null int64
# Utilities                                 1265 non-null int64
# dtypes: float64(22), int64(38), object(17)
# memory usage: 770.9+ KB

# %%
x1 = df['Scope_1_tCO2e']
y1 = df['Carbon']
X = sm.add_constant(x1)
model_sm = sm.OLS(y1,X)
results = model_sm.fit()
results.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                 Carbon   R-squared:                       0.131
# Model:                            OLS   Adj. R-squared:                  0.131
# Method:                 Least Squares   F-statistic:                     190.7
# Date:                Wed, 12 Feb 2020   Prob (F-statistic):           1.64e-40
# Time:                        11:45:54   Log-Likelihood:                -10757.
# No. Observations:                1265   AIC:                         2.152e+04
# Df Residuals:                    1263   BIC:                         2.153e+04
# Df Model:                           1
# Covariance Type:            nonrobust
# =================================================================================
#                     coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------
# const           326.3641     34.410      9.485      0.000     258.857     393.871
# Scope_1_tCO2e  3.324e-05   2.41e-06     13.811      0.000    2.85e-05     3.8e-05
# ==============================================================================
# Omnibus:                     1546.611   Durbin-Watson:                   1.920
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):           190627.896
# Skew:                           6.331   Prob(JB):                         0.00
# Kurtosis:                      61.791   Cond. No.                     1.47e+07
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 1.47e+07. This might indicate that there are
# strong multicollinearity or other numerical problems.
# """

# %%
df.head()
# Out:
#     Unnamed:_0        Company_Name Listed HQ_Country             GICS_Sector  \
# 2            3              YPF SA    Yes  Argentina                  Energy
# 5            6  Aristocrat Leisure    Yes  Australia  Consumer Discretionary
# 6            7                 ALS    Yes  Australia             Industrials
# 18          19        BHP Billiton    Yes  Australia               Materials
# 21          22     BlueScope Steel    Yes  Australia               Materials
#
#    Accounting_Year_End  Reported_Scope_1_tCO2e  Estimated_Scope_1_tCO2e  \
# 2           31/12/2016                     0.0               12000000.0
# 5           29/09/2016                     0.0                  21000.0
# 6           30/03/2017                     0.0                  12000.0
# 18          30/06/2016              11292000.0                      0.0
# 21          28/06/2017               8145000.0                      0.0
#
#                                     Scope_1_source  Scope_1_quality_flag  \
# 2   Estimated: Oil & Gas Extraction, O&G  Refining                   6.0
# 5                             Estimated: Gamma GLM                   3.0
# 6                             Estimated: Gamma GLM                   4.0
# 18                        Reported: CDP (Reviewed)                   7.0
# 21            Reported: Company Filings (Reviewed)                   7.0
#
#    Reported_market-based_Scope_2_tCO2e  Note  \
# 2                                  NaN   NA
# 5                                  NaN   NA
# 6                                  NaN   NA
# 18                        6,720,000.00
# 21                                 NaN   NA
#
#     Reported_location-based_Scope_2_tCO2e  \
# 2                                     0.0
# 5                                     0.0
# 6                                     0.0
# 18                              6720000.0
# 21                                    0.0
#
#     Estimated_location-based_Scope_2_tCO2e  \
# 2                                1200000.0
# 5                                  54000.0
# 6                                   3700.0
# 18                                     0.0
# 21                               2800000.0
#
#                         Location-based_Scope_2_source  \
# 2      Estimated: Oil & Gas Extraction, O&G  Refining
# 5   Estimated: IEA National Grid Emissions Factor ...
# 6   Estimated: IEA National Grid Emissions Factor ...
# 18                           Reported: CDP (Reviewed)
# 21           Estimated: Iron & Steel Mills, Gamma GLM
#
#     Location-based_Scope_2_quality_flag  \
# 2                                   6.0
# 5                                   2.0
# 6                                   5.0
# 18                                  7.0
# 21                                  6.0
#
#                              Scope_2_company_comments  \
# 2                                                 NaN
# 5                                                 NaN
# 6                                                 NaN
# 18  In accordance with the new GHG Protocol Scope ...
# 21                                                NaN
#
#     GHG_revenue_intensity_tCO2e/mmUSD Scope_2_figure_used_for_intensity  \
# 2                              926.11                    Location-based
# 5                               47.82                    Location-based
# 6                               16.39                    Location-based
# 18                             582.69                      Market-based
# 21                            1363.86                    Location-based
#
#     amplification.wordsindex  DeAmplification.wordsindex  HE_negativeindex  \
# 2                         48                          84               165
# 5                        114                          35                20
# 6                        123                         190                71
# 18                       120                         133                97
# 21                       112                          89                60
#
#     HE_positiveindex  angerindex  anticipationindex  disgustindex  fearindex  \
# 2                110         102                123           221         87
# 5                143         135                 98            76         99
# 6                 78         115                 78           145         87
# 18               105         136                117           118        132
# 21               121         131                 98            90        103
#
#     joyindex  sadnessindex  surpriseindex  trustindex  LMnegativeindex  \
# 2         69            86            102          72               89
# 5        112            64             89          94               73
# 6         83            64             86          79              106
# 18       104            73            125         109              103
# 21       100            71            109          82               80
#
#     LMpositiveindex  LMuncertaintyindex  BasicNegativeWordsindex  \
# 2                62                  75                       98
# 5               119                  70                       71
# 6                93                 113                       84
# 18              128                  89                      123
# 21              129                  92                       84
#
#     PositivePolarisedindex  NegativePolarisedindex  PowerWordsindex  \
# 2                       73                      98               94
# 5                      113                      71               87
# 6                      103                      84               88
# 18                     110                     123              123
# 21                     121                      84               91
#
#     PrudentialNegativeindex  PrudentialPositiveindex  \
# 2                        55                       89
# 5                        86                       94
# 6                        98                      153
# 18                      105                      136
# 21                       90                      106
#
#    PrudentialTopNegativeindex Strategyindex  Financial.termsindex  \
# 2                         170             0                    98
# 5                           0           316                    99
# 6                         364            31                    90
# 18                          0            44                   115
# 21                         81            69                    80
#
#     Regulationindex  Technologyindex Healthcareindex Environmentindex  \
# 2               111               14               0               87
# 5                75              266               0               65
# 6                36               10              75              186
# 18               51               43              47              133
# 21               48               30               0              345
#
#    Socialindex  Governanceindex  ESGindex  LMuncertaintyindex.1  \
# 2           26              130        90                  0.23
# 5        1,375               70       451                  0.26
# 6            0               40        80                  0.08
# 18          52                0        61                  0.18
# 21         143              117       184                  0.16
#
#     Regulationindex.1  Environmentindex.1  Socialindex.1  Governanceindex.1  \
# 2                0.12                0.23           0.07               0.13
# 5                0.24                0.00           0.15               0.01
# 6                0.19                0.25           0.21               0.15
# 18               0.06                0.17           0.28               0.19
# 21               0.19                0.06           0.08               0.05
#
#     ESGindex.1    ISIN_lower   2016vol   2017vol   2018vol   2019vol  \
# 2         0.27  arp9897x1319  0.024063  0.021263  0.030650  0.029235
# 5         0.14  au000000all7  0.019772  0.013992  0.018362  0.019044
# 6         0.11           NaN       NaN       NaN       NaN       NaN
# 18        0.09  au000000bhp4  0.027883  0.014745  0.015851  0.012937
# 21        0.13  au000000bsl0  0.028576  0.024869  0.022911  0.024640
#
#     VolFactor       Carbon  Scope_1_tCO2e  Scope_2_tCO2e  Scope_1_and_2_tCO2e  \
# 2    0.064662   926.111720     12000000.0      1200000.0           13200000.0
# 5    0.254386    47.820958        21000.0        54000.0              75000.0
# 6    0.000000    16.392587        12000.0         3700.0              15700.0
# 18   0.505514   582.686335     11292000.0      6720000.0           18012000.0
# 21   0.119298  1363.862928      8145000.0      2800000.0           10945000.0
#
#     Consumer_Discretionary  Consumer_Staples  Energy  Financials  Health_Care  \
# 2                        0                 0       1           0            0
# 5                        1                 0       0           0            0
# 6                        0                 0       0           0            0
# 18                       0                 0       0           0            0
# 21                       0                 0       0           0            0
#
#     Industrials  Information_Technology  Materials  Real_Estate  \
# 2             0                       0          0            0
# 5             0                       0          0            0
# 6             1                       0          0            0
# 18            0                       0          1            0
# 21            0                       0          1            0
#
#     Telecommunication_Services  Utilities
# 2                            0          0
# 5                            0          0
# 6                            0          0
# 18                           0          0
# 21                           0          0

# %%
X_step = df
X_step_clean = df[['HE_negativeindex', 'HE_positiveindex',
       'angerindex', 'anticipationindex', 'disgustindex', 'fearindex',
       'joyindex', 'sadnessindex', 'surpriseindex', 'trustindex',
       'LMnegativeindex', 'LMpositiveindex', 'LMuncertaintyindex',
       'BasicNegativeWordsindex', 'PositivePolarisedindex',
       'NegativePolarisedindex', 'PowerWordsindex', 'PrudentialNegativeindex',
       'PrudentialPositiveindex']]
y_step = list(df['Carbon'])
def stepwise_selection(X_step_clean, y_step,
                       initial_list=[],
                       threshold_in=0.0001,
                       threshold_out = 0.005,
                       verbose=True):
    """ Perform a forward-backward feature selection
    based on p-value from statsmodels.api.OLS
    Arguments:
        X - pandas.DataFrame with candidate features
        y - list-like with the target
        initial_list - list of features to start with (column names of X)
        threshold_in - include a feature if its p-value < threshold_in
        threshold_out - exclude a feature if its p-value > threshold_out
        verbose - whether to print the sequence of inclusions and exclusions
    Returns: list of selected features
    Always set threshold_in < threshold_out to avoid infinite looping.
    See https://en.wikipedia.org/wiki/Stepwise_regression for the details
    """
    included = list(initial_list)
    while True:
        changed=False
        # forward step
        excluded = list(set(X_step_clean.columns)-set(included))
        new_pval = pd.Series(index=excluded)
        for new_column in excluded:
            model = sm.OLS(y_step, sm.add_constant(pd.DataFrame(X_step_clean[included+[new_column]]))).fit()
            new_pval[new_column] = model.pvalues[new_column]
        best_pval = new_pval.min()
        if best_pval < threshold_in:
            best_feature = new_pval.idxmin()
            included.append(best_feature)
            changed=True
            if verbose:
                print('Add  {:30} with p-value {:.6}'.format(best_feature, best_pval))
        # backward step
        model = sm.OLS(y_step, sm.add_constant(pd.DataFrame(X_step_clean[included]))).fit()
        # use all coefs except intercept
        pvalues = model.pvalues.iloc[1:]
        worst_pval = pvalues.max() # null if pvalues is empty
        if worst_pval > threshold_out:
            changed=True
            worst_feature = pvalues.argmax()
            included.remove(worst_feature)
            if verbose:
                print('Drop {:30} with p-value {:.6}'.format(worst_feature, worst_pval))
        if not changed:
            break
    return included
result = stepwise_selection(X_step_clean, X_step['Carbon'], verbose=True)
print('resulting features:')
print(result)
# Out:
# Add  HE_positiveindex               with p-value 1.24589e-09
# Add  angerindex                     with p-value 1.3863e-05
# resulting features:
# ['HE_positiveindex', 'angerindex']

# %%
formula = 'Carbon ~ C(GICS_Sector) + Scope_1_tCO2e'
lm = ols(formula, df).fit()
table = sm.stats.anova_lm(lm, typ=1)
print(table)
# Out:
#                     df        sum_sq       mean_sq          F        PR(>F)
# C(GICS_Sector)    10.0  5.545273e+08  5.545273e+07  48.203795  1.086362e-81
# Scope_1_tCO2e      1.0  7.670248e+07  7.670248e+07  66.675719  7.735351e-16
# Residual        1253.0  1.441427e+09  1.150381e+06        NaN           NaN
