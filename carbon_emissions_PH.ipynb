# %%
import pandas as pd

# %%
df3 = pd.read_csv('predicting_carbon_emissions.csv')

# %%
df3.head(10)
# Out:
#    Account ID                          Company Name Listed    Ticker  \
# 0       30238       Agencia de Proteccion Ambiental    Yes    ADN LN
# 1       59859       Sociedad Comercial del Plata SA    Yes   COME AR
# 2        1408  Banco de Galicia y Buenos Aires S.A.    Yes   GALI AR
# 3       20949                                YPF SA    Yes   YPFD AR
# 4       57626                        Australia Post    Yes  1067Z AU
# 5         351                            AGL Energy    Yes    AGL AU
# 6         934                    Aristocrat Leisure    Yes    ALL AU
# 7       36574                                   ALS    Yes    ALQ AU
# 8         674                                 Amcor    Yes    AMC AU
# 9         724                                   AMP    Yes    AMP AU
#
#            ISIN HQ Country             GICS Sector Accounting Year End  \
# 0           NaN        NaN                     NaN          29/09/2016
# ...

# %%
df3.shape
# Out:
# (3987, 65)

# %%
df3.describe()
# Out:
#          Account ID  Scope 1 quality flag  \
# count   3987.000000           2811.000000
# mean   24596.869827              5.807542
# std    18243.727416              1.401687
# min       44.000000              1.000000
# 25%     9831.500000              5.000000
# 50%    20592.000000              6.000000
# 75%    37703.000000              7.000000
# max    73540.000000              7.000000
#
#        Location-based Scope 2 quality flag  \
# count                          2805.000000
# mean                              5.818182
# std                               1.211758
# min                               1.000000
# 25%                               5.000000
# 50%                               6.000000
# 75%                               7.000000
# max                               7.000000
#
#        GHG revenue intensity (tCO2e/mmUSD)  amplification.wordsindex  \
# count                          3936.000000               3987.000000
# ...

# %%
#df3['ISIN'] == 'AU000000AGL7'

# %%
df3.count()
# Out:
# Account ID                        3987
# Company Name                      3987
# Listed                            3987
# Ticker                            3583
# ISIN                              3075
#                                   ...
# 2017vol                           2781
# 2018vol                           2720
# 2019vol                           2709
# VolFactor                         3987
# Carbon Emission  (tCO2e/mmUSD)    3987
# Length: 65, dtype: int64

# %%
df
# Out:
#    Account ID Company Name Listed  Ticker          ISIN HQ Country  \
# 5         351   AGL Energy    Yes  AGL AU  AU000000AGL7  Australia
#
#   GICS Sector Accounting Year End  Reported Scope 1 (tCO2e)   \
# 5   Utilities          30/06/2016              43,258,798.00
#
#    Estimated Scope 1 (tCO2e)   ... Socialindex.1  Governanceindex.1  \
# 5                         NaN  ...          0.28               0.31
#
#   ESGindex.1    ISIN lower   2016vol   2017vol   2018vol   2019vol VolFactor  \
# 5       0.32  au000000agl7  0.013876  0.012527  0.013894  0.013356  0.492732
#
#    Carbon Emission  (tCO2e/mmUSD)
# 5                     5390.042347
#
# [1 rows x 65 columns]

# %%
df3.sort_values(['ISIN'])
# Out:
#       Account ID                  Company Name Listed       Ticker ISIN  \
# 1858       54924                     Entra Asa    Yes     ENTRA NO    0
# 2330       54930                  Recipharm Ab    Yes     RECIB SS    0
# 2338       16406          Scandic Hotels Group    Yes      SHOT SS    0
# 88         60580              Vicinity Centres    Yes       VCX AU    0
# 2737       63525                    Logtek Ltd    Yes  1728160Z LN    0
# ...          ...                           ...    ...          ...  ...
# 3961       28692  West Pharmaceutical Services    Yes       WST US  NaN
# 3962       33928              WEST CORPORATION    Yes      WSTC US  NaN
# 3966       44273      Wolverine World Wide Inc    Yes       WWW US  NaN
# 3976       13416                 XPO Logistics    Yes       XPO US  NaN
# 3983       33252                          ZAYO    Yes      ZAYO US  NaN
#
#           HQ Country                 GICS Sector Accounting Year End  \
# ...

# %%
df3.head(100)
# Out:
#     Account ID                          Company Name Listed    Ticker  \
# 0        30238       Agencia de Proteccion Ambiental    Yes    ADN LN
# 1        59859       Sociedad Comercial del Plata SA    Yes   COME AR
# 2         1408  Banco de Galicia y Buenos Aires S.A.    Yes   GALI AR
# 3        20949                                YPF SA    Yes   YPFD AR
# 4        57626                        Australia Post    Yes  1067Z AU
# ..         ...                                   ...    ...       ...
# 95       20792                         WorleyParsons    Yes    WOR AU
# 96       20780                    Woolworths Limited    Yes    WOW AU
# 97       20771                    Woodside Petroleum    Yes    WPL AU
# 98       20614                         Western Areas    Yes    WSA AU
# 99       31962                AGRANA Beteiligungs-AG    Yes    AGR AV
#
#             ISIN HQ Country       GICS Sector Accounting Year End  \
# ...

# %%
sectors = (df3['GICS Sector'].unique())

# %%
sectors
# Out:
# array([nan, 'Energy', 'Financials', 'Industrials', 'Utilities',
#        'Consumer Discretionary', 'Materials', 'Health Care',
#        'Consumer Staples', 'Real Estate', 'Information Technology',
#        'Telecommunication Services'], dtype=object)

# %%
len(company)
# Out:
# 3987
